# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
merchant_df = pd.read_csv(r"C:\Users\Rudra\Desktop\smart-transaction-ledger\data\bronze\merchant_db.csv")

# %%
merchant_df
# Out:
#   merchant_id  merchant_name expected_category  avg_transaction_value  \
# 0        M001      Starbucks   Food & Beverage                    300
# 1        M002         Amazon          Shopping                   1500
# 2        M003       Flipkart        E-commerce                   1200
# 3        M004     Big Bazaar           Grocery                    800
# 4        M005            OLA         Transport                    200
# 5        M006          DMart           Grocery                   1000
# 6        M007     Local Shop               NaN                    100
# 7        M008          Apple       Electronics                  25000
# 8        M009         Swiggy   Food & Beverage                    400
# 9        M010  Unknown Store               ???                    500
#
#   risk_level
# 0        low
# 1     medium
# 2     medium
# 3        low
# 4        low
# 5        low
# 6       high
# 7     medium
# 8        low
# 9       high

# %% [markdown]
# Assumptions:
#
# - We don't know store means
# - That is the Local Store

# %% [markdown]
# ## 1

# %%
merchant_df.loc[merchant_df['merchant_name'] == "Unknown Store"]
# Out:
#   merchant_id  merchant_name expected_category  avg_transaction_value  \
# 9        M010  Unknown Store               ???                    500
#
#   risk_level
# 9       high

# %%
merchant_df['merchant_name'] = merchant_df['merchant_name'].replace('Unknown Store', 'Local Shop')

# %%
merchant_df
# Out:
#   merchant_id merchant_name expected_category  avg_transaction_value  \
# 0        M001     Starbucks   Food & Beverage                    300
# 1        M002        Amazon          Shopping                   1500
# 2        M003      Flipkart        E-commerce                   1200
# 3        M004    Big Bazaar           Grocery                    800
# 4        M005           OLA         Transport                    200
# 5        M006         DMart           Grocery                   1000
# 6        M007    Local Shop               NaN                    100
# 7        M008         Apple       Electronics                  25000
# 8        M009        Swiggy   Food & Beverage                    400
# 9        M010    Local Shop               ???                    500
#
#   risk_level
# 0        low
# 1     medium
# 2     medium
# 3        low
# 4        low
# 5        low
# 6       high
# 7     medium
# 8        low
# 9       high

# %% [markdown]
# ## 2

# %%
merchant_df['expected_category'] = merchant_df['expected_category'].replace({'???': 'Others', 'NaN': 'Others'})

# %%
merchant_df['expected_category'] = merchant_df['expected_category'].fillna('Others')

# %%
merchant_df
# Out:
#   merchant_id merchant_name expected_category  avg_transaction_value  \
# 0        M001     Starbucks   Food & Beverage                    300
# 1        M002        Amazon          Shopping                   1500
# 2        M003      Flipkart        E-commerce                   1200
# 3        M004    Big Bazaar           Grocery                    800
# 4        M005           OLA         Transport                    200
# 5        M006         DMart           Grocery                   1000
# 6        M007    Local Shop            Others                    100
# 7        M008         Apple       Electronics                  25000
# 8        M009        Swiggy   Food & Beverage                    400
# 9        M010    Local Shop            Others                    500
#
#   risk_level
# 0        low
# 1     medium
# 2     medium
# 3        low
# 4        low
# 5        low
# 6       high
# 7     medium
# 8        low
# 9       high

# %% [markdown]
# ## 3 Label Encoding

# %%
merchant_df['risk_level_encoded'] = merchant_df['risk_level'].replace({'low': 1, 'medium': 2, 'high': 3})
# Out:
# C:\Users\Rudra\AppData\Local\Temp\ipykernel_2176\356277347.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   merchant_df['risk_level_encoded'] = merchant_df['risk_level'].replace({'low': 1, 'medium': 2, 'high': 3})

# %%
merchant_df
# Out:
#   merchant_id merchant_name expected_category  avg_transaction_value  \
# 0        M001     Starbucks   Food & Beverage                    300
# 1        M002        Amazon          Shopping                   1500
# 2        M003      Flipkart        E-commerce                   1200
# 3        M004    Big Bazaar           Grocery                    800
# 4        M005           OLA         Transport                    200
# 5        M006         DMart           Grocery                   1000
# 6        M007    Local Shop            Others                    100
# 7        M008         Apple       Electronics                  25000
# 8        M009        Swiggy   Food & Beverage                    400
# 9        M010    Local Shop            Others                    500
#
#   risk_level  risk_level_encoded
# 0        low                   1
# 1     medium                   2
# 2     medium                   2
# 3        low                   1
# 4        low                   1
# ...
